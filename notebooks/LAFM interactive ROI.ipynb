# %% [markdown]
# # LAFM interactive workbench
#
# Run the single code cell below. Select an ROI by pressing the left mouse button on the input image, dragging, and releasing. The particle workflow detects particles in every frame, averages their frame-specific crops into a reference, then re-detects particles using that average reference. Leveling and filtering are available but remain off by default for the testing images.

# %%
# %matplotlib widget
from pathlib import Path
import importlib
import pnanolocz.lafm_notebook_ui as lafm_ui
importlib.reload(lafm_ui)

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

workbench = lafm_ui.launch_lafm_workbench(PROJECT_ROOT)
